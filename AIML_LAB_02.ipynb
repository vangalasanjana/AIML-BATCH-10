# %% [markdown]
# <a href="https://colab.research.google.com/github/vangalasanjana/AIML-BATCH-10/blob/main/AIML_LAB_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 import numpy as np
 from queue import Queue
 graph={0:[1,3],1:[0,2,3],2:[4,1,5],3:[4,0,1],4:[2,3,5,],5:[4,2],6:[]}
 print("The adjacency List representing the graph is:")
 print(graph)
# Out:
# The adjacency List representing the graph is:
# {0: [1, 3], 1: [0, 2, 3], 2: [4, 1, 5], 3: [4, 0, 1], 4: [2, 3, 5], 5: [4, 2], 6: []}

# %%
def bfs(graph,source):
  Q=Queue()
  visited_vertices=set()
  Q.put(source)
  visited_vertices.update({0})
  while not Q.empty():
                    vertex=Q.get()
                    print(vertex,end="-->")
                    for u in graph[vertex]:
                          if u not in visited_vertices:
                            Q.put(u)
                            visited_vertices.update({u})
print("BFS transversal of graph with source 1 is:")
bfs(graph,0)
# Out:
# BFS transversal of graph with source 1 is:
# 0-->1-->3-->2-->4-->5-->

# %% [markdown]
# ##Part-01 Implement Breadth  First search Algorithm
# ![bfs.png](data:image/png;base64,...![dfs.png](data:image/png;base64,...![dfs.png](data:image/png;base64,...![dfs.png](data:image/png;base64,...![dfs.png.png](data:image/png;base64,...)))))![bfs.png](data:image/png;base64,...![dfs.png](data:image/png;base64,...))

# %%
import numpy as np
from queue import Queue
graph={0: [1,2,3], 1:[0,2], 2:[0,1,3,5],
       3: [0,2,4], 4: [3,5,7], 5: [4,6,7], 6:[5,7], 7:[4,5,6],8:[]}
print("the adjacency list representing the graph is:")
print(graph)
# Out:
# the adjacency list representing the graph is:
# {0: [1, 2, 3], 1: [0, 2], 2: [0, 1, 3, 5], 3: [0, 2, 4], 4: [3, 5, 7], 5: [4, 6, 7], 6: [5, 7], 7: [4, 5, 6], 8: []}

# %%
def bfs(graph, source):
   Q=Queue()
   visited_vertices= set()
   Q.put(source)
   visited_vertices.update({source})
   while not Q.empty():
     vertex = Q.get()
     print(vertex, end="-->")
     for u in graph[vertex]:
         if u not in visited_vertices:
              Q.put(u)
              visited_vertices.update({u})
print("BFS traversal of graph with source 0 is:")
bfs(graph,0)
# Out:
# BFS traversal of graph with source 0 is:
# 0-->1-->2-->3-->5-->4-->6-->7-->

# %% [markdown]
# ## Part-02 Implement Depth First search Algorithm
# ![dfs.png](attachment:dfs.png)

# %%
graph1={
'A' : ['C','D','G'],
'B' : ['A'],
'C' : ['A','D','F'],
'D' : ['A','C','E','G','H'],
'E' : ['D','F','H'],
'F' : ['C','E'],
'G' : ['A','D','H'],
'H' : ['D','E','G']}
print(graph1)
# Out:
# {'A': ['C', 'D', 'G'], 'B': ['A'], 'C': ['A', 'D', 'F'], 'D': ['A', 'C', 'E', 'G', 'H'], 'E': ['D', 'F', 'H'], 'F': ['C', 'E'], 'G': ['A', 'D', 'H'], 'H': ['D', 'E', 'G']}

# %%
def dfs(graph,node,visited):
   if node not in visited:
       visited.append(node)
       for k in graph[node]:
           dfs(graph,k,visited)
   return visited

visited = dfs(graph1,'B',[])
print(visited)
# Out:
# ['B', 'A', 'C', 'D', 'E', 'F', 'H', 'G']

# %% [markdown]
# ## Part-03: Implement A*
